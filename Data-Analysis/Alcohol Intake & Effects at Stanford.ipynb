# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = [18, 4]

# %%
alcdf = pd.read_excel('./../Formatted-Data/stanford_county_report.xlsx', sheet_name="General Data", index_col=[0,1])
alcdf = alcdf.drop(columns="Notes") # Remove Notes
alcdf = alcdf.T
display(alcdf)
# Out:
# Data      Medical Alcohol Transport to ER                                      \
# Category                             Fall Winter Spring Frosh Sophmore Junior
# 2006-2007                            24.0    6.0   17.0   NaN      NaN    NaN
# 2007-2008                            16.0    8.0    7.0   NaN      NaN    NaN
# 2008-2009                            21.0   13.0   10.0   NaN      NaN    NaN
# 2009-2010                             NaN    NaN    NaN  27.0     11.0    9.0
# 2010-2011                             NaN    NaN    NaN  24.0     19.0    6.0
# 2011-2012                             NaN    NaN    NaN  29.0     17.0    3.0
# 2012-2013                             NaN    NaN    NaN  26.0      9.0    3.0
# 2013-2014                             NaN    NaN    NaN  28.0     19.0    2.0
# 2014-2015                             NaN    NaN    NaN  23.0     10.0    5.0
# 2015-2016                             NaN    NaN    NaN  28.0     19.0    4.0
# ...

# %%
alcdf["Medical Alcohol Transport to ER"]["Total"].plot()

# %%
alcdf["Total Number of Registered Parties"]["All"].plot()

# %%
alcdf["Parties rejected for approval by the University"]["NoCat"].plot()

# %%
alcdf["Originator of Party"].plot()
